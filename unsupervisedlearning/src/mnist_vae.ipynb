# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

import numpy as np

from sklearn.preprocessing import MinMaxScaler

from torchvision import datasets
import torchvision.transforms as T

## My own modules
import viz_utils as vu
import train_utils as tu
import model_utils as mu
###

import imp
imp.reload(vu)
imp.reload(mu)
imp.reload(tu)
# Out:
# /var/folders/wb/ttr9x7pn27q1_rp5vtjfr0s00000gn/T/ipykernel_3394/3262691840.py:22: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'train_utils' from '/Users/mghifary/Work/govtech/codes/AI/unslearning/train_utils.py'>

# %%
DATA_DIR = "../data"
MODEL_DIR = "../models"

EPOCHS = 100
BATCH_SIZE = 256
LEARNING_RATE = 1e-3

dh = 512
dz = 20
beta = 0.75

# Persistent file to store the model
model_path = os.path.join(MODEL_DIR, "vae_ep%d_h%d_z%d_beta075_mnist.pth" % (EPOCHS, dh, dz))

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load dataset
training_data = datasets.MNIST(
    root=DATA_DIR, 
    train=True, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

test_data = datasets.MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

# %%
# Create data loaders
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
training_data.classes
# Out:
# ['0 - zero',
#  '1 - one',
#  '2 - two',
#  '3 - three',
#  '4 - four',
#  '5 - five',
#  '6 - six',
#  '7 - seven',
#  '8 - eight',
#  '9 - nine']

# %%
# c = 1
# print(training_data.classes[c])
# idx = (training_data.targets == c)
# X2d = training_data.data[idx]

# idx_t = (test_data.targets == c)
# X2d_t = test_data.data[idx_t]

X2d = training_data.data
X2d_t = test_data.data

# %%
grid = vu.set_grid(X2d, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
X2d_np = X2d.numpy()
(n, dx1, dx2) = X2d_np.shape

X = np.reshape(X2d_np, (-1, dx1 * dx2))

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
Xn = scaler.fit_transform(X)

# %%
V = np.reshape(Xn, (-1, dx1, dx2))
# V = V.astype('uint8')
grid = vu.set_grid(V, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
print(f"Using {DEVICE} device")

# Define model
model = mu.VAE(d_in=dx1*dx2, d_z=dz, d_h=dh).to(DEVICE)
print(model)
# Out:
# Using cpu device
# VAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=40, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=20, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=784, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
loss_fn = tu.vae_loss

optimizer = optim.Adam(
    model.parameters(), 
    lr=LEARNING_RATE
)

# %%
for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train_vae(train_dataloader, model, loss_fn, optimizer, beta=beta)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    test_loss = tu.test_vae(test_dataloader, model, loss_fn, beta=beta)
    print(f" > Test reconstruction loss: {test_loss:>.2f}")
    
    # Save model
    torch.save(model.state_dict(), model_path)
    print(f"Model {model_path} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 100
#  ------------
# Loss: 46463.449219 [    0]/60000
# Loss: 11329.616211 [25600]/60000
# Loss: 10331.187500 [51200]/60000
#  > Training time: 2.63 seconds
#  > Test reconstruction loss: 8606.83
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 2 out of 100
#  ------------
# Loss: 9467.448242 [    0]/60000
# Loss: 8806.516602 [25600]/60000
# Loss: 8687.871094 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 6995.54
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 3 out of 100
#  ------------
# Loss: 8188.311523 [    0]/60000
# Loss: 7941.711914 [25600]/60000
# Loss: 8003.644531 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 6368.39
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 4 out of 100
#  ------------
# Loss: 7707.776855 [    0]/60000
# Loss: 7706.665039 [25600]/60000
# Loss: 7601.194336 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 6120.61
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 5 out of 100
#  ------------
# Loss: 7359.263184 [    0]/60000
# Loss: 7365.273438 [25600]/60000
# Loss: 7430.942383 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5971.66
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 6 out of 100
#  ------------
# Loss: 7233.455078 [    0]/60000
# Loss: 7279.358398 [25600]/60000
# Loss: 7359.085938 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5769.20
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 7 out of 100
#  ------------
# Loss: 7105.795898 [    0]/60000
# Loss: 7080.561035 [25600]/60000
# Loss: 7212.687988 [51200]/60000
#  > Training time: 2.55 seconds
#  > Test reconstruction loss: 5671.45
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 8 out of 100
#  ------------
# Loss: 6927.867188 [    0]/60000
# Loss: 7042.028809 [25600]/60000
# Loss: 7131.323730 [51200]/60000
#  > Training time: 2.55 seconds
#  > Test reconstruction loss: 5592.81
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 9 out of 100
#  ------------
# Loss: 6939.567871 [    0]/60000
# Loss: 6994.292480 [25600]/60000
# Loss: 7090.997559 [51200]/60000
#  > Training time: 2.54 seconds
#  > Test reconstruction loss: 5606.37
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 10 out of 100
#  ------------
# Loss: 6775.010742 [    0]/60000
# Loss: 6969.690918 [25600]/60000
# Loss: 7038.027344 [51200]/60000
#  > Training time: 2.55 seconds
#  > Test reconstruction loss: 5513.46
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 11 out of 100
#  ------------
# Loss: 6943.314941 [    0]/60000
# Loss: 6921.787109 [25600]/60000
# Loss: 6961.595703 [51200]/60000
#  > Training time: 2.54 seconds
#  > Test reconstruction loss: 5498.19
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 12 out of 100
#  ------------
# Loss: 6854.120117 [    0]/60000
# Loss: 6874.106445 [25600]/60000
# Loss: 6966.387695 [51200]/60000
#  > Training time: 2.55 seconds
#  > Test reconstruction loss: 5459.50
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 13 out of 100
#  ------------
# Loss: 6744.683105 [    0]/60000
# Loss: 6832.737305 [25600]/60000
# Loss: 6995.876953 [51200]/60000
#  > Training time: 2.55 seconds
#  > Test reconstruction loss: 5561.89
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 14 out of 100
#  ------------
# Loss: 6813.455078 [    0]/60000
# Loss: 6806.043457 [25600]/60000
# Loss: 6931.812988 [51200]/60000
#  > Training time: 2.78 seconds
#  > Test reconstruction loss: 5375.02
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 15 out of 100
#  ------------
# Loss: 6725.052734 [    0]/60000
# Loss: 6766.729492 [25600]/60000
# Loss: 6858.813477 [51200]/60000
#  > Training time: 2.56 seconds
#  > Test reconstruction loss: 5458.11
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 16 out of 100
#  ------------
# Loss: 6717.351562 [    0]/60000
# Loss: 6885.968750 [25600]/60000
# Loss: 6770.286133 [51200]/60000
#  > Training time: 2.56 seconds
#  > Test reconstruction loss: 5453.98
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 17 out of 100
#  ------------
# Loss: 6649.823730 [    0]/60000
# Loss: 6705.144531 [25600]/60000
# Loss: 6958.420898 [51200]/60000
#  > Training time: 2.61 seconds
#  > Test reconstruction loss: 5358.05
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 18 out of 100
#  ------------
# Loss: 6581.609375 [    0]/60000
# Loss: 6816.097656 [25600]/60000
# Loss: 6837.252930 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5349.10
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 19 out of 100
#  ------------
# Loss: 6530.049805 [    0]/60000
# Loss: 6700.277344 [25600]/60000
# Loss: 6801.750977 [51200]/60000
#  > Training time: 2.70 seconds
#  > Test reconstruction loss: 5315.99
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 20 out of 100
#  ------------
# Loss: 6628.902344 [    0]/60000
# Loss: 6696.248047 [25600]/60000
# Loss: 6827.653320 [51200]/60000
#  > Training time: 3.15 seconds
#  > Test reconstruction loss: 5383.86
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 21 out of 100
#  ------------
# Loss: 6513.937012 [    0]/60000
# Loss: 6717.551758 [25600]/60000
# Loss: 6776.188477 [51200]/60000
#  > Training time: 3.18 seconds
#  > Test reconstruction loss: 5423.11
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 22 out of 100
#  ------------
# Loss: 6650.021484 [    0]/60000
# Loss: 6613.891113 [25600]/60000
# Loss: 6773.426270 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5337.54
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 23 out of 100
#  ------------
# Loss: 6549.728516 [    0]/60000
# Loss: 6654.586914 [25600]/60000
# Loss: 6786.530273 [51200]/60000
#  > Training time: 2.62 seconds
#  > Test reconstruction loss: 5276.75
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 24 out of 100
#  ------------
# Loss: 6548.338867 [    0]/60000
# Loss: 6661.901855 [25600]/60000
# Loss: 6759.841309 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5199.12
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 25 out of 100
#  ------------
# Loss: 6606.082031 [    0]/60000
# Loss: 6638.735352 [25600]/60000
# Loss: 6775.294434 [51200]/60000
#  > Training time: 2.60 seconds
#  > Test reconstruction loss: 5319.94
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 26 out of 100
#  ------------
# Loss: 6627.233398 [    0]/60000
# Loss: 6591.693848 [25600]/60000
# Loss: 6734.930664 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5328.82
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 27 out of 100
#  ------------
# Loss: 6554.384766 [    0]/60000
# Loss: 6569.617676 [25600]/60000
# Loss: 6678.583008 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5308.40
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 28 out of 100
#  ------------
# Loss: 6447.005859 [    0]/60000
# Loss: 6576.612305 [25600]/60000
# Loss: 6697.111328 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5204.36
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 29 out of 100
#  ------------
# Loss: 6574.608398 [    0]/60000
# Loss: 6525.970703 [25600]/60000
# Loss: 6659.937500 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5283.04
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 30 out of 100
#  ------------
# Loss: 6516.440430 [    0]/60000
# Loss: 6581.657227 [25600]/60000
# Loss: 6674.055664 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5277.88
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 31 out of 100
#  ------------
# Loss: 6491.666016 [    0]/60000
# Loss: 6519.704102 [25600]/60000
# Loss: 6705.471680 [51200]/60000
#  > Training time: 2.60 seconds
#  > Test reconstruction loss: 5268.42
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 32 out of 100
#  ------------
# Loss: 6529.257812 [    0]/60000
# Loss: 6534.083008 [25600]/60000
# Loss: 6691.607422 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5249.48
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 33 out of 100
#  ------------
# Loss: 6404.187500 [    0]/60000
# Loss: 6545.110840 [25600]/60000
# Loss: 6700.552734 [51200]/60000
#  > Training time: 2.66 seconds
#  > Test reconstruction loss: 5269.54
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 34 out of 100
#  ------------
# Loss: 6485.066406 [    0]/60000
# Loss: 6566.784180 [25600]/60000
# Loss: 6628.682617 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5238.64
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 35 out of 100
#  ------------
# Loss: 6513.676758 [    0]/60000
# Loss: 6484.691406 [25600]/60000
# Loss: 6611.096680 [51200]/60000
#  > Training time: 2.65 seconds
#  > Test reconstruction loss: 5270.54
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 36 out of 100
#  ------------
# Loss: 6452.279785 [    0]/60000
# Loss: 6561.979492 [25600]/60000
# Loss: 6626.434082 [51200]/60000
#  > Training time: 2.70 seconds
#  > Test reconstruction loss: 5255.86
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 37 out of 100
#  ------------
# Loss: 6431.522949 [    0]/60000
# Loss: 6601.834473 [25600]/60000
# Loss: 6604.371582 [51200]/60000
#  > Training time: 3.07 seconds
#  > Test reconstruction loss: 5239.26
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 38 out of 100
#  ------------
# Loss: 6372.657227 [    0]/60000
# Loss: 6457.310547 [25600]/60000
# Loss: 6629.473633 [51200]/60000
#  > Training time: 3.20 seconds
#  > Test reconstruction loss: 5248.27
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 39 out of 100
#  ------------
# Loss: 6392.103516 [    0]/60000
# Loss: 6465.017578 [25600]/60000
# Loss: 6595.920410 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5215.70
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 40 out of 100
#  ------------
# Loss: 6411.754883 [    0]/60000
# Loss: 6478.177734 [25600]/60000
# Loss: 6581.606934 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5218.45
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 41 out of 100
#  ------------
# Loss: 6355.830078 [    0]/60000
# Loss: 6380.640625 [25600]/60000
# Loss: 6578.209961 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5286.56
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 42 out of 100
#  ------------
# Loss: 6497.819824 [    0]/60000
# Loss: 6545.248047 [25600]/60000
# Loss: 6542.119141 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5190.81
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 43 out of 100
#  ------------
# Loss: 6349.749023 [    0]/60000
# Loss: 6511.286621 [25600]/60000
# Loss: 6610.133301 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5251.83
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 44 out of 100
#  ------------
# Loss: 6479.569336 [    0]/60000
# Loss: 6533.150879 [25600]/60000
# Loss: 6494.346191 [51200]/60000
#  > Training time: 2.60 seconds
#  > Test reconstruction loss: 5153.10
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 45 out of 100
#  ------------
# Loss: 6328.138672 [    0]/60000
# Loss: 6429.625000 [25600]/60000
# Loss: 6568.505859 [51200]/60000
#  > Training time: 3.04 seconds
#  > Test reconstruction loss: 5235.55
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 46 out of 100
#  ------------
# Loss: 6417.056641 [    0]/60000
# Loss: 6466.997070 [25600]/60000
# Loss: 6597.098633 [51200]/60000
#  > Training time: 2.72 seconds
#  > Test reconstruction loss: 5224.05
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 47 out of 100
#  ------------
# Loss: 6470.712891 [    0]/60000
# Loss: 6470.776855 [25600]/60000
# Loss: 6580.840820 [51200]/60000
#  > Training time: 2.68 seconds
#  > Test reconstruction loss: 5205.18
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 48 out of 100
#  ------------
# Loss: 6386.557617 [    0]/60000
# Loss: 6395.096680 [25600]/60000
# Loss: 6522.904297 [51200]/60000
#  > Training time: 2.74 seconds
#  > Test reconstruction loss: 5182.74
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 49 out of 100
#  ------------
# Loss: 6294.993164 [    0]/60000
# Loss: 6379.272461 [25600]/60000
# Loss: 6535.960938 [51200]/60000
#  > Training time: 2.85 seconds
#  > Test reconstruction loss: 5248.36
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 50 out of 100
#  ------------
# Loss: 6378.184082 [    0]/60000
# Loss: 6466.210938 [25600]/60000
# Loss: 6469.867188 [51200]/60000
#  > Training time: 2.85 seconds
#  > Test reconstruction loss: 5183.44
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 51 out of 100
#  ------------
# Loss: 6329.729492 [    0]/60000
# Loss: 6412.975586 [25600]/60000
# Loss: 6512.975586 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5200.18
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 52 out of 100
#  ------------
# Loss: 6309.800781 [    0]/60000
# Loss: 6407.204102 [25600]/60000
# Loss: 6521.156250 [51200]/60000
#  > Training time: 2.98 seconds
#  > Test reconstruction loss: 5183.74
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 53 out of 100
#  ------------
# Loss: 6325.620117 [    0]/60000
# Loss: 6390.338867 [25600]/60000
# Loss: 6496.957520 [51200]/60000
#  > Training time: 2.78 seconds
#  > Test reconstruction loss: 5188.15
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 54 out of 100
#  ------------
# Loss: 6326.617676 [    0]/60000
# Loss: 6416.405762 [25600]/60000
# Loss: 6429.782715 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5240.93
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 55 out of 100
#  ------------
# Loss: 6315.407227 [    0]/60000
# Loss: 6364.263672 [25600]/60000
# Loss: 6533.264648 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5235.45
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 56 out of 100
#  ------------
# Loss: 6359.641602 [    0]/60000
# Loss: 6419.677734 [25600]/60000
# Loss: 6531.101562 [51200]/60000
#  > Training time: 2.82 seconds
#  > Test reconstruction loss: 5200.15
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 57 out of 100
#  ------------
# Loss: 6368.080566 [    0]/60000
# Loss: 6356.687500 [25600]/60000
# Loss: 6566.830078 [51200]/60000
#  > Training time: 2.76 seconds
#  > Test reconstruction loss: 5123.44
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 58 out of 100
#  ------------
# Loss: 6267.433105 [    0]/60000
# Loss: 6410.637207 [25600]/60000
# Loss: 6466.958008 [51200]/60000
#  > Training time: 2.72 seconds
#  > Test reconstruction loss: 5171.90
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 59 out of 100
#  ------------
# Loss: 6297.678711 [    0]/60000
# Loss: 6379.428711 [25600]/60000
# Loss: 6450.144531 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5202.73
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 60 out of 100
#  ------------
# Loss: 6314.577148 [    0]/60000
# Loss: 6309.979004 [25600]/60000
# Loss: 6514.813477 [51200]/60000
#  > Training time: 2.72 seconds
#  > Test reconstruction loss: 5186.00
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 61 out of 100
#  ------------
# Loss: 6292.952148 [    0]/60000
# Loss: 6354.774902 [25600]/60000
# Loss: 6426.593262 [51200]/60000
#  > Training time: 2.96 seconds
#  > Test reconstruction loss: 5150.48
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 62 out of 100
#  ------------
# Loss: 6319.247070 [    0]/60000
# Loss: 6339.416504 [25600]/60000
# Loss: 6511.293945 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5171.29
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 63 out of 100
#  ------------
# Loss: 6255.752930 [    0]/60000
# Loss: 6356.562500 [25600]/60000
# Loss: 6522.129883 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5153.31
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 64 out of 100
#  ------------
# Loss: 6189.214355 [    0]/60000
# Loss: 6277.804199 [25600]/60000
# Loss: 6513.580078 [51200]/60000
#  > Training time: 3.03 seconds
#  > Test reconstruction loss: 5140.63
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 65 out of 100
#  ------------
# Loss: 6401.479492 [    0]/60000
# Loss: 6364.085449 [25600]/60000
# Loss: 6565.874023 [51200]/60000
#  > Training time: 2.65 seconds
#  > Test reconstruction loss: 5185.14
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 66 out of 100
#  ------------
# Loss: 6191.759766 [    0]/60000
# Loss: 6388.611328 [25600]/60000
# Loss: 6401.927246 [51200]/60000
#  > Training time: 2.80 seconds
#  > Test reconstruction loss: 5128.09
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 67 out of 100
#  ------------
# Loss: 6257.624023 [    0]/60000
# Loss: 6375.908691 [25600]/60000
# Loss: 6380.840820 [51200]/60000
#  > Training time: 3.22 seconds
#  > Test reconstruction loss: 5190.07
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 68 out of 100
#  ------------
# Loss: 6227.084961 [    0]/60000
# Loss: 6380.035645 [25600]/60000
# Loss: 6439.777344 [51200]/60000
#  > Training time: 3.33 seconds
#  > Test reconstruction loss: 5133.53
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 69 out of 100
#  ------------
# Loss: 6292.844238 [    0]/60000
# Loss: 6373.866211 [25600]/60000
# Loss: 6410.664551 [51200]/60000
#  > Training time: 2.65 seconds
#  > Test reconstruction loss: 5258.82
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 70 out of 100
#  ------------
# Loss: 6283.922363 [    0]/60000
# Loss: 6265.557129 [25600]/60000
# Loss: 6393.968750 [51200]/60000
#  > Training time: 2.67 seconds
#  > Test reconstruction loss: 5235.15
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 71 out of 100
#  ------------
# Loss: 6305.703613 [    0]/60000
# Loss: 6375.671387 [25600]/60000
# Loss: 6421.720703 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5156.64
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 72 out of 100
#  ------------
# Loss: 6245.196289 [    0]/60000
# Loss: 6331.725586 [25600]/60000
# Loss: 6439.334961 [51200]/60000
#  > Training time: 2.78 seconds
#  > Test reconstruction loss: 5150.01
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 73 out of 100
#  ------------
# Loss: 6273.153320 [    0]/60000
# Loss: 6265.581543 [25600]/60000
# Loss: 6401.744141 [51200]/60000
#  > Training time: 2.61 seconds
#  > Test reconstruction loss: 5178.19
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 74 out of 100
#  ------------
# Loss: 6237.777344 [    0]/60000
# Loss: 6332.959473 [25600]/60000
# Loss: 6526.395996 [51200]/60000
#  > Training time: 2.69 seconds
#  > Test reconstruction loss: 5242.69
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 75 out of 100
#  ------------
# Loss: 6371.931641 [    0]/60000
# Loss: 6288.165039 [25600]/60000
# Loss: 6483.724609 [51200]/60000
#  > Training time: 2.63 seconds
#  > Test reconstruction loss: 5096.49
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 76 out of 100
#  ------------
# Loss: 6270.274414 [    0]/60000
# Loss: 6325.755859 [25600]/60000
# Loss: 6483.080078 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5160.31
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 77 out of 100
#  ------------
# Loss: 6236.848633 [    0]/60000
# Loss: 6230.015625 [25600]/60000
# Loss: 6421.185547 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5196.62
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 78 out of 100
#  ------------
# Loss: 6254.379883 [    0]/60000
# Loss: 6254.825195 [25600]/60000
# Loss: 6512.362305 [51200]/60000
#  > Training time: 2.62 seconds
#  > Test reconstruction loss: 5136.35
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 79 out of 100
#  ------------
# Loss: 6199.910645 [    0]/60000
# Loss: 6241.787598 [25600]/60000
# Loss: 6366.410156 [51200]/60000
#  > Training time: 2.86 seconds
#  > Test reconstruction loss: 5129.70
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 80 out of 100
#  ------------
# Loss: 6225.515625 [    0]/60000
# Loss: 6389.831055 [25600]/60000
# Loss: 6441.162109 [51200]/60000
#  > Training time: 2.86 seconds
#  > Test reconstruction loss: 5158.90
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 81 out of 100
#  ------------
# Loss: 6229.038086 [    0]/60000
# Loss: 6292.873535 [25600]/60000
# Loss: 6395.089355 [51200]/60000
#  > Training time: 2.77 seconds
#  > Test reconstruction loss: 5192.35
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 82 out of 100
#  ------------
# Loss: 6286.987793 [    0]/60000
# Loss: 6218.337402 [25600]/60000
# Loss: 6420.637695 [51200]/60000
#  > Training time: 2.69 seconds
#  > Test reconstruction loss: 5215.28
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 83 out of 100
#  ------------
# Loss: 6240.973633 [    0]/60000
# Loss: 6300.020508 [25600]/60000
# Loss: 6523.664062 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5159.05
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 84 out of 100
#  ------------
# Loss: 6199.865723 [    0]/60000
# Loss: 6209.776367 [25600]/60000
# Loss: 6447.986328 [51200]/60000
#  > Training time: 2.68 seconds
#  > Test reconstruction loss: 5150.13
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 85 out of 100
#  ------------
# Loss: 6198.801270 [    0]/60000
# Loss: 6284.159180 [25600]/60000
# Loss: 6467.830566 [51200]/60000
#  > Training time: 2.72 seconds
#  > Test reconstruction loss: 5219.82
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 86 out of 100
#  ------------
# Loss: 6280.533203 [    0]/60000
# Loss: 6371.281738 [25600]/60000
# Loss: 6405.286133 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5114.40
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 87 out of 100
#  ------------
# Loss: 6181.458008 [    0]/60000
# Loss: 6320.858398 [25600]/60000
# Loss: 6412.124023 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5098.42
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 88 out of 100
#  ------------
# Loss: 6229.138672 [    0]/60000
# Loss: 6215.991211 [25600]/60000
# Loss: 6394.353516 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5144.68
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 89 out of 100
#  ------------
# Loss: 6263.279297 [    0]/60000
# Loss: 6275.188477 [25600]/60000
# Loss: 6412.073242 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5182.31
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 90 out of 100
#  ------------
# Loss: 6197.002930 [    0]/60000
# Loss: 6315.030762 [25600]/60000
# Loss: 6331.250977 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5142.17
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 91 out of 100
#  ------------
# Loss: 6183.936035 [    0]/60000
# Loss: 6299.759277 [25600]/60000
# Loss: 6301.476074 [51200]/60000
#  > Training time: 2.67 seconds
#  > Test reconstruction loss: 5096.00
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 92 out of 100
#  ------------
# Loss: 6206.997559 [    0]/60000
# Loss: 6274.295898 [25600]/60000
# Loss: 6353.162109 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5171.47
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 93 out of 100
#  ------------
# Loss: 6205.402344 [    0]/60000
# Loss: 6242.330566 [25600]/60000
# Loss: 6428.544434 [51200]/60000
#  > Training time: 2.63 seconds
#  > Test reconstruction loss: 5166.52
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 94 out of 100
#  ------------
# Loss: 6175.136719 [    0]/60000
# Loss: 6262.102539 [25600]/60000
# Loss: 6362.420898 [51200]/60000
#  > Training time: 2.60 seconds
#  > Test reconstruction loss: 5182.30
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 95 out of 100
#  ------------
# Loss: 6228.626465 [    0]/60000
# Loss: 6220.798828 [25600]/60000
# Loss: 6411.984375 [51200]/60000
#  > Training time: 2.60 seconds
#  > Test reconstruction loss: 5172.38
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 96 out of 100
#  ------------
# Loss: 6195.427734 [    0]/60000
# Loss: 6249.767578 [25600]/60000
# Loss: 6417.314941 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5206.66
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 97 out of 100
#  ------------
# Loss: 6168.483398 [    0]/60000
# Loss: 6248.344727 [25600]/60000
# Loss: 6412.091797 [51200]/60000
#  > Training time: 2.57 seconds
#  > Test reconstruction loss: 5170.15
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 98 out of 100
#  ------------
# Loss: 6198.964355 [    0]/60000
# Loss: 6318.813477 [25600]/60000
# Loss: 6424.025391 [51200]/60000
#  > Training time: 2.59 seconds
#  > Test reconstruction loss: 5159.04
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 99 out of 100
#  ------------
# Loss: 6110.528320 [    0]/60000
# Loss: 6312.469727 [25600]/60000
# Loss: 6322.409668 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5204.45
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Epoch 100 out of 100
#  ------------
# Loss: 6201.196289 [    0]/60000
# Loss: 6272.773438 [25600]/60000
# Loss: 6363.009766 [51200]/60000
#  > Training time: 2.58 seconds
#  > Test reconstruction loss: 5128.51
# Model ../models/vae_ep100_h512_z20_beta075_mnist.pth stored!
# Done!
