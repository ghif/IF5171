# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

import numpy as np

from sklearn.preprocessing import MinMaxScaler

from torchvision import datasets
import torchvision.transforms as T

## My own modules
import viz_utils as vu
import train_utils as tu
import model_utils as mu
###

import imp
imp.reload(vu)
imp.reload(mu)
imp.reload(tu)
# Out:
# /var/folders/wb/ttr9x7pn27q1_rp5vtjfr0s00000gn/T/ipykernel_2873/3262691840.py:22: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'train_utils' from '/Users/mghifary/Work/govtech/codes/AI/deeplearning/train_utils.py'>

# %%
DATA_DIR = "../data"
MODEL_DIR = "../models"

EPOCHS = 100
BATCH_SIZE = 128
LEARNING_RATE = 1e-3
dz = 300

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load dataset
training_data = datasets.FashionMNIST(
    root=DATA_DIR, 
    train=True, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

test_data = datasets.FashionMNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

# %%
# Create data loaders
train_dataloader = DataLoader(training_data, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE)

# %%
training_data.classes
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
# c = 1
# print(training_data.classes[c])
# idx = (training_data.targets == c)
# X2d = training_data.data[idx]

# idx_t = (test_data.targets == c)
# X2d_t = test_data.data[idx_t]

X2d = training_data.data
X2d_t = test_data.data

# %%
grid = vu.set_grid(X2d, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
X2d_np = X2d.numpy()
(n, dx1, dx2) = X2d_np.shape

X = np.reshape(X2d_np, (-1, dx1 * dx2))

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
Xn = scaler.fit_transform(X)

# %%
V = np.reshape(Xn, (-1, dx1, dx2))
# V = V.astype('uint8')
grid = vu.set_grid(V, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
print(f"Using {DEVICE} device")

# Define model
model = mu.MLPAutoEnc(d_in=dx1*dx2, d_z=dz, d_h=512).to(DEVICE)
print(model)

# Persistent file to store the model
model_path = os.path.join(MODEL_DIR, "mlpautoenc_sigm_ep100_fmnist.pth")
# Out:
# Using cpu device
# MLPAutoEnc(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=300, bias=True)
#     (3): Sigmoid()
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=300, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=784, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
loss_fn = nn.MSELoss()

# optimizer = optim.SGD(
#     model.parameters(), 
#     lr=LEARNING_RATE
# )

optimizer = optim.Adam(
    model.parameters(), 
    lr=LEARNING_RATE
)

# %%
for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train_uns(train_dataloader, model, loss_fn, optimizer)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    test_loss = tu.test_uns(test_dataloader, model, loss_fn)
    print(f" > Test reconstruction loss: {test_loss:>.2f}")
    
    # Save model
    torch.save(model.state_dict(), model_path)
    print(f"Model {model_path} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 100
#  ------------
# Loss: 0.173268 [    0]/60000
# Loss: 0.040946 [12800]/60000
# Loss: 0.027967 [25600]/60000
# Loss: 0.023466 [38400]/60000
# Loss: 0.021605 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.02
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 2 out of 100
#  ------------
# Loss: 0.022130 [    0]/60000
# Loss: 0.020021 [12800]/60000
# Loss: 0.019704 [25600]/60000
# Loss: 0.018424 [38400]/60000
# Loss: 0.017763 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.02
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 3 out of 100
#  ------------
# Loss: 0.017824 [    0]/60000
# Loss: 0.016720 [12800]/60000
# Loss: 0.016327 [25600]/60000
# Loss: 0.015745 [38400]/60000
# Loss: 0.015127 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 4 out of 100
#  ------------
# Loss: 0.015016 [    0]/60000
# Loss: 0.014073 [12800]/60000
# Loss: 0.013994 [25600]/60000
# Loss: 0.013836 [38400]/60000
# Loss: 0.013507 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 5 out of 100
#  ------------
# Loss: 0.013235 [    0]/60000
# Loss: 0.012535 [12800]/60000
# Loss: 0.012620 [25600]/60000
# Loss: 0.012683 [38400]/60000
# Loss: 0.012518 [51200]/60000
#  > Training time: 3.75 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 6 out of 100
#  ------------
# Loss: 0.012306 [    0]/60000
# Loss: 0.011370 [12800]/60000
# Loss: 0.011541 [25600]/60000
# Loss: 0.011703 [38400]/60000
# Loss: 0.011692 [51200]/60000
#  > Training time: 3.77 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 7 out of 100
#  ------------
# Loss: 0.011213 [    0]/60000
# Loss: 0.010499 [12800]/60000
# Loss: 0.010727 [25600]/60000
# Loss: 0.010838 [38400]/60000
# Loss: 0.011731 [51200]/60000
#  > Training time: 3.64 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 8 out of 100
#  ------------
# Loss: 0.010403 [    0]/60000
# Loss: 0.009755 [12800]/60000
# Loss: 0.010044 [25600]/60000
# Loss: 0.010297 [38400]/60000
# Loss: 0.010934 [51200]/60000
#  > Training time: 3.63 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 9 out of 100
#  ------------
# Loss: 0.009873 [    0]/60000
# Loss: 0.009211 [12800]/60000
# Loss: 0.009586 [25600]/60000
# Loss: 0.009685 [38400]/60000
# Loss: 0.009900 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 10 out of 100
#  ------------
# Loss: 0.009277 [    0]/60000
# Loss: 0.008780 [12800]/60000
# Loss: 0.009139 [25600]/60000
# Loss: 0.009258 [38400]/60000
# Loss: 0.009507 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 11 out of 100
#  ------------
# Loss: 0.008853 [    0]/60000
# Loss: 0.008483 [12800]/60000
# Loss: 0.008779 [25600]/60000
# Loss: 0.008941 [38400]/60000
# Loss: 0.009152 [51200]/60000
#  > Training time: 3.65 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 12 out of 100
#  ------------
# Loss: 0.008523 [    0]/60000
# Loss: 0.008105 [12800]/60000
# Loss: 0.008648 [25600]/60000
# Loss: 0.008638 [38400]/60000
# Loss: 0.008858 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 13 out of 100
#  ------------
# Loss: 0.008177 [    0]/60000
# Loss: 0.007806 [12800]/60000
# Loss: 0.008454 [25600]/60000
# Loss: 0.008407 [38400]/60000
# Loss: 0.008722 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 14 out of 100
#  ------------
# Loss: 0.007929 [    0]/60000
# Loss: 0.007537 [12800]/60000
# Loss: 0.007923 [25600]/60000
# Loss: 0.008079 [38400]/60000
# Loss: 0.008267 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 15 out of 100
#  ------------
# Loss: 0.007724 [    0]/60000
# Loss: 0.007269 [12800]/60000
# Loss: 0.007613 [25600]/60000
# Loss: 0.007842 [38400]/60000
# Loss: 0.008063 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 16 out of 100
#  ------------
# Loss: 0.007550 [    0]/60000
# Loss: 0.007052 [12800]/60000
# Loss: 0.007335 [25600]/60000
# Loss: 0.007611 [38400]/60000
# Loss: 0.007789 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 17 out of 100
#  ------------
# Loss: 0.007272 [    0]/60000
# Loss: 0.006871 [12800]/60000
# Loss: 0.007158 [25600]/60000
# Loss: 0.007438 [38400]/60000
# Loss: 0.007596 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 18 out of 100
#  ------------
# Loss: 0.006986 [    0]/60000
# Loss: 0.006687 [12800]/60000
# Loss: 0.006939 [25600]/60000
# Loss: 0.007246 [38400]/60000
# Loss: 0.007380 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 19 out of 100
#  ------------
# Loss: 0.006872 [    0]/60000
# Loss: 0.006529 [12800]/60000
# Loss: 0.006715 [25600]/60000
# Loss: 0.007151 [38400]/60000
# Loss: 0.007211 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 20 out of 100
#  ------------
# Loss: 0.006802 [    0]/60000
# Loss: 0.006401 [12800]/60000
# Loss: 0.006533 [25600]/60000
# Loss: 0.007013 [38400]/60000
# Loss: 0.007074 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 21 out of 100
#  ------------
# Loss: 0.006777 [    0]/60000
# Loss: 0.006217 [12800]/60000
# Loss: 0.006422 [25600]/60000
# Loss: 0.006829 [38400]/60000
# Loss: 0.007304 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 22 out of 100
#  ------------
# Loss: 0.006340 [    0]/60000
# Loss: 0.006094 [12800]/60000
# Loss: 0.006500 [25600]/60000
# Loss: 0.006645 [38400]/60000
# Loss: 0.007022 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 23 out of 100
#  ------------
# Loss: 0.006188 [    0]/60000
# Loss: 0.005943 [12800]/60000
# Loss: 0.006300 [25600]/60000
# Loss: 0.006484 [38400]/60000
# Loss: 0.006865 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 24 out of 100
#  ------------
# Loss: 0.006010 [    0]/60000
# Loss: 0.005793 [12800]/60000
# Loss: 0.005995 [25600]/60000
# Loss: 0.006335 [38400]/60000
# Loss: 0.006566 [51200]/60000
#  > Training time: 3.66 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 25 out of 100
#  ------------
# Loss: 0.005908 [    0]/60000
# Loss: 0.005746 [12800]/60000
# Loss: 0.005867 [25600]/60000
# Loss: 0.006195 [38400]/60000
# Loss: 0.006442 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 26 out of 100
#  ------------
# Loss: 0.005851 [    0]/60000
# Loss: 0.005582 [12800]/60000
# Loss: 0.005738 [25600]/60000
# Loss: 0.006072 [38400]/60000
# Loss: 0.006334 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 27 out of 100
#  ------------
# Loss: 0.005815 [    0]/60000
# Loss: 0.005462 [12800]/60000
# Loss: 0.005651 [25600]/60000
# Loss: 0.005990 [38400]/60000
# Loss: 0.006233 [51200]/60000
#  > Training time: 3.73 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 28 out of 100
#  ------------
# Loss: 0.005574 [    0]/60000
# Loss: 0.005405 [12800]/60000
# Loss: 0.005577 [25600]/60000
# Loss: 0.005864 [38400]/60000
# Loss: 0.006204 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 29 out of 100
#  ------------
# Loss: 0.005623 [    0]/60000
# Loss: 0.005348 [12800]/60000
# Loss: 0.005525 [25600]/60000
# Loss: 0.005852 [38400]/60000
# Loss: 0.006149 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 30 out of 100
#  ------------
# Loss: 0.005425 [    0]/60000
# Loss: 0.005212 [12800]/60000
# Loss: 0.005579 [25600]/60000
# Loss: 0.005702 [38400]/60000
# Loss: 0.006051 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 31 out of 100
#  ------------
# Loss: 0.005295 [    0]/60000
# Loss: 0.005128 [12800]/60000
# Loss: 0.005293 [25600]/60000
# Loss: 0.005573 [38400]/60000
# Loss: 0.005872 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 32 out of 100
#  ------------
# Loss: 0.005186 [    0]/60000
# Loss: 0.005069 [12800]/60000
# Loss: 0.005256 [25600]/60000
# Loss: 0.005513 [38400]/60000
# Loss: 0.005754 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 33 out of 100
#  ------------
# Loss: 0.005114 [    0]/60000
# Loss: 0.004952 [12800]/60000
# Loss: 0.005131 [25600]/60000
# Loss: 0.005459 [38400]/60000
# Loss: 0.005676 [51200]/60000
#  > Training time: 3.80 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 34 out of 100
#  ------------
# Loss: 0.005103 [    0]/60000
# Loss: 0.004885 [12800]/60000
# Loss: 0.005030 [25600]/60000
# Loss: 0.005455 [38400]/60000
# Loss: 0.005663 [51200]/60000
#  > Training time: 4.43 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 35 out of 100
#  ------------
# Loss: 0.005034 [    0]/60000
# Loss: 0.004868 [12800]/60000
# Loss: 0.005248 [25600]/60000
# Loss: 0.005299 [38400]/60000
# Loss: 0.005573 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 36 out of 100
#  ------------
# Loss: 0.004936 [    0]/60000
# Loss: 0.004791 [12800]/60000
# Loss: 0.004984 [25600]/60000
# Loss: 0.005224 [38400]/60000
# Loss: 0.005455 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 37 out of 100
#  ------------
# Loss: 0.004869 [    0]/60000
# Loss: 0.004677 [12800]/60000
# Loss: 0.004785 [25600]/60000
# Loss: 0.005128 [38400]/60000
# Loss: 0.005372 [51200]/60000
#  > Training time: 3.78 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 38 out of 100
#  ------------
# Loss: 0.004786 [    0]/60000
# Loss: 0.004615 [12800]/60000
# Loss: 0.004708 [25600]/60000
# Loss: 0.005067 [38400]/60000
# Loss: 0.005308 [51200]/60000
#  > Training time: 3.75 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 39 out of 100
#  ------------
# Loss: 0.004732 [    0]/60000
# Loss: 0.004604 [12800]/60000
# Loss: 0.004664 [25600]/60000
# Loss: 0.005059 [38400]/60000
# Loss: 0.005239 [51200]/60000
#  > Training time: 3.73 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 40 out of 100
#  ------------
# Loss: 0.004710 [    0]/60000
# Loss: 0.004579 [12800]/60000
# Loss: 0.004718 [25600]/60000
# Loss: 0.005057 [38400]/60000
# Loss: 0.005205 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 41 out of 100
#  ------------
# Loss: 0.004612 [    0]/60000
# Loss: 0.004488 [12800]/60000
# Loss: 0.004796 [25600]/60000
# Loss: 0.004924 [38400]/60000
# Loss: 0.005177 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 42 out of 100
#  ------------
# Loss: 0.004532 [    0]/60000
# Loss: 0.004435 [12800]/60000
# Loss: 0.004668 [25600]/60000
# Loss: 0.004860 [38400]/60000
# Loss: 0.005093 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 43 out of 100
#  ------------
# Loss: 0.004466 [    0]/60000
# Loss: 0.004317 [12800]/60000
# Loss: 0.004510 [25600]/60000
# Loss: 0.004784 [38400]/60000
# Loss: 0.004964 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 44 out of 100
#  ------------
# Loss: 0.004479 [    0]/60000
# Loss: 0.004274 [12800]/60000
# Loss: 0.004429 [25600]/60000
# Loss: 0.004687 [38400]/60000
# Loss: 0.004968 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 45 out of 100
#  ------------
# Loss: 0.004305 [    0]/60000
# Loss: 0.004348 [12800]/60000
# Loss: 0.004367 [25600]/60000
# Loss: 0.004641 [38400]/60000
# Loss: 0.004923 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 46 out of 100
#  ------------
# Loss: 0.004343 [    0]/60000
# Loss: 0.004182 [12800]/60000
# Loss: 0.004385 [25600]/60000
# Loss: 0.004631 [38400]/60000
# Loss: 0.004870 [51200]/60000
#  > Training time: 3.70 seconds
#  > Test reconstruction loss: 0.01
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 47 out of 100
#  ------------
# Loss: 0.004668 [    0]/60000
# Loss: 0.004179 [12800]/60000
# Loss: 0.004309 [25600]/60000
# Loss: 0.004603 [38400]/60000
# Loss: 0.004784 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 48 out of 100
#  ------------
# Loss: 0.004344 [    0]/60000
# Loss: 0.004139 [12800]/60000
# Loss: 0.004225 [25600]/60000
# Loss: 0.004524 [38400]/60000
# Loss: 0.004724 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 49 out of 100
#  ------------
# Loss: 0.004238 [    0]/60000
# Loss: 0.004065 [12800]/60000
# Loss: 0.004198 [25600]/60000
# Loss: 0.004447 [38400]/60000
# Loss: 0.004669 [51200]/60000
#  > Training time: 3.82 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 50 out of 100
#  ------------
# Loss: 0.004126 [    0]/60000
# Loss: 0.004043 [12800]/60000
# Loss: 0.004173 [25600]/60000
# Loss: 0.004414 [38400]/60000
# Loss: 0.004616 [51200]/60000
#  > Training time: 4.39 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 51 out of 100
#  ------------
# Loss: 0.004055 [    0]/60000
# Loss: 0.004156 [12800]/60000
# Loss: 0.004107 [25600]/60000
# Loss: 0.004384 [38400]/60000
# Loss: 0.004665 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 52 out of 100
#  ------------
# Loss: 0.004074 [    0]/60000
# Loss: 0.004096 [12800]/60000
# Loss: 0.004023 [25600]/60000
# Loss: 0.004330 [38400]/60000
# Loss: 0.004668 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 53 out of 100
#  ------------
# Loss: 0.004059 [    0]/60000
# Loss: 0.003906 [12800]/60000
# Loss: 0.003981 [25600]/60000
# Loss: 0.004278 [38400]/60000
# Loss: 0.004741 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 54 out of 100
#  ------------
# Loss: 0.003956 [    0]/60000
# Loss: 0.003867 [12800]/60000
# Loss: 0.003925 [25600]/60000
# Loss: 0.004247 [38400]/60000
# Loss: 0.004483 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 55 out of 100
#  ------------
# Loss: 0.003949 [    0]/60000
# Loss: 0.003869 [12800]/60000
# Loss: 0.003981 [25600]/60000
# Loss: 0.004220 [38400]/60000
# Loss: 0.004468 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 56 out of 100
#  ------------
# Loss: 0.003889 [    0]/60000
# Loss: 0.003893 [12800]/60000
# Loss: 0.003973 [25600]/60000
# Loss: 0.004219 [38400]/60000
# Loss: 0.004450 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 57 out of 100
#  ------------
# Loss: 0.003888 [    0]/60000
# Loss: 0.003807 [12800]/60000
# Loss: 0.003861 [25600]/60000
# Loss: 0.004169 [38400]/60000
# Loss: 0.004458 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 58 out of 100
#  ------------
# Loss: 0.004043 [    0]/60000
# Loss: 0.003905 [12800]/60000
# Loss: 0.003803 [25600]/60000
# Loss: 0.004142 [38400]/60000
# Loss: 0.004387 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 59 out of 100
#  ------------
# Loss: 0.003828 [    0]/60000
# Loss: 0.003710 [12800]/60000
# Loss: 0.003773 [25600]/60000
# Loss: 0.004081 [38400]/60000
# Loss: 0.004336 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 60 out of 100
#  ------------
# Loss: 0.003780 [    0]/60000
# Loss: 0.003679 [12800]/60000
# Loss: 0.003728 [25600]/60000
# Loss: 0.004040 [38400]/60000
# Loss: 0.004288 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 61 out of 100
#  ------------
# Loss: 0.003749 [    0]/60000
# Loss: 0.003710 [12800]/60000
# Loss: 0.003820 [25600]/60000
# Loss: 0.004024 [38400]/60000
# Loss: 0.004336 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 62 out of 100
#  ------------
# Loss: 0.003744 [    0]/60000
# Loss: 0.003668 [12800]/60000
# Loss: 0.003730 [25600]/60000
# Loss: 0.004000 [38400]/60000
# Loss: 0.004241 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 63 out of 100
#  ------------
# Loss: 0.003700 [    0]/60000
# Loss: 0.003657 [12800]/60000
# Loss: 0.003694 [25600]/60000
# Loss: 0.003993 [38400]/60000
# Loss: 0.004212 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 64 out of 100
#  ------------
# Loss: 0.003742 [    0]/60000
# Loss: 0.003622 [12800]/60000
# Loss: 0.003773 [25600]/60000
# Loss: 0.003956 [38400]/60000
# Loss: 0.004333 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 65 out of 100
#  ------------
# Loss: 0.003722 [    0]/60000
# Loss: 0.003586 [12800]/60000
# Loss: 0.003636 [25600]/60000
# Loss: 0.003933 [38400]/60000
# Loss: 0.004213 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 66 out of 100
#  ------------
# Loss: 0.003657 [    0]/60000
# Loss: 0.003564 [12800]/60000
# Loss: 0.003591 [25600]/60000
# Loss: 0.003909 [38400]/60000
# Loss: 0.004124 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 67 out of 100
#  ------------
# Loss: 0.003604 [    0]/60000
# Loss: 0.003482 [12800]/60000
# Loss: 0.003641 [25600]/60000
# Loss: 0.003858 [38400]/60000
# Loss: 0.004099 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 68 out of 100
#  ------------
# Loss: 0.003568 [    0]/60000
# Loss: 0.003472 [12800]/60000
# Loss: 0.003546 [25600]/60000
# Loss: 0.003828 [38400]/60000
# Loss: 0.004126 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 69 out of 100
#  ------------
# Loss: 0.003565 [    0]/60000
# Loss: 0.003455 [12800]/60000
# Loss: 0.003522 [25600]/60000
# Loss: 0.003813 [38400]/60000
# Loss: 0.004050 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 70 out of 100
#  ------------
# Loss: 0.003528 [    0]/60000
# Loss: 0.003404 [12800]/60000
# Loss: 0.003478 [25600]/60000
# Loss: 0.003784 [38400]/60000
# Loss: 0.004001 [51200]/60000
#  > Training time: 3.87 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 71 out of 100
#  ------------
# Loss: 0.003517 [    0]/60000
# Loss: 0.003394 [12800]/60000
# Loss: 0.003470 [25600]/60000
# Loss: 0.003784 [38400]/60000
# Loss: 0.004091 [51200]/60000
#  > Training time: 4.45 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 72 out of 100
#  ------------
# Loss: 0.003625 [    0]/60000
# Loss: 0.003377 [12800]/60000
# Loss: 0.003443 [25600]/60000
# Loss: 0.003857 [38400]/60000
# Loss: 0.004004 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 73 out of 100
#  ------------
# Loss: 0.003670 [    0]/60000
# Loss: 0.003349 [12800]/60000
# Loss: 0.003527 [25600]/60000
# Loss: 0.003905 [38400]/60000
# Loss: 0.004056 [51200]/60000
#  > Training time: 3.72 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 74 out of 100
#  ------------
# Loss: 0.003548 [    0]/60000
# Loss: 0.003351 [12800]/60000
# Loss: 0.003408 [25600]/60000
# Loss: 0.003740 [38400]/60000
# Loss: 0.003921 [51200]/60000
#  > Training time: 3.68 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 75 out of 100
#  ------------
# Loss: 0.003494 [    0]/60000
# Loss: 0.003275 [12800]/60000
# Loss: 0.003386 [25600]/60000
# Loss: 0.003667 [38400]/60000
# Loss: 0.003907 [51200]/60000
#  > Training time: 3.74 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 76 out of 100
#  ------------
# Loss: 0.003392 [    0]/60000
# Loss: 0.003273 [12800]/60000
# Loss: 0.003370 [25600]/60000
# Loss: 0.003630 [38400]/60000
# Loss: 0.003888 [51200]/60000
#  > Training time: 3.80 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 77 out of 100
#  ------------
# Loss: 0.003361 [    0]/60000
# Loss: 0.003270 [12800]/60000
# Loss: 0.003288 [25600]/60000
# Loss: 0.003610 [38400]/60000
# Loss: 0.003862 [51200]/60000
#  > Training time: 3.86 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 78 out of 100
#  ------------
# Loss: 0.003361 [    0]/60000
# Loss: 0.003236 [12800]/60000
# Loss: 0.003309 [25600]/60000
# Loss: 0.003612 [38400]/60000
# Loss: 0.003864 [51200]/60000
#  > Training time: 4.23 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 79 out of 100
#  ------------
# Loss: 0.003341 [    0]/60000
# Loss: 0.003353 [12800]/60000
# Loss: 0.003369 [25600]/60000
# Loss: 0.003646 [38400]/60000
# Loss: 0.003928 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 80 out of 100
#  ------------
# Loss: 0.003460 [    0]/60000
# Loss: 0.003203 [12800]/60000
# Loss: 0.003281 [25600]/60000
# Loss: 0.003652 [38400]/60000
# Loss: 0.003810 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 81 out of 100
#  ------------
# Loss: 0.003415 [    0]/60000
# Loss: 0.003169 [12800]/60000
# Loss: 0.003290 [25600]/60000
# Loss: 0.003564 [38400]/60000
# Loss: 0.003767 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 82 out of 100
#  ------------
# Loss: 0.003325 [    0]/60000
# Loss: 0.003159 [12800]/60000
# Loss: 0.003277 [25600]/60000
# Loss: 0.003512 [38400]/60000
# Loss: 0.003757 [51200]/60000
#  > Training time: 3.70 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 83 out of 100
#  ------------
# Loss: 0.003236 [    0]/60000
# Loss: 0.003177 [12800]/60000
# Loss: 0.003224 [25600]/60000
# Loss: 0.003498 [38400]/60000
# Loss: 0.003809 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 84 out of 100
#  ------------
# Loss: 0.003251 [    0]/60000
# Loss: 0.003158 [12800]/60000
# Loss: 0.003196 [25600]/60000
# Loss: 0.003510 [38400]/60000
# Loss: 0.003850 [51200]/60000
#  > Training time: 3.81 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 85 out of 100
#  ------------
# Loss: 0.003363 [    0]/60000
# Loss: 0.003129 [12800]/60000
# Loss: 0.003337 [25600]/60000
# Loss: 0.003800 [38400]/60000
# Loss: 0.003768 [51200]/60000
#  > Training time: 3.70 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 86 out of 100
#  ------------
# Loss: 0.003368 [    0]/60000
# Loss: 0.003132 [12800]/60000
# Loss: 0.003236 [25600]/60000
# Loss: 0.003506 [38400]/60000
# Loss: 0.003678 [51200]/60000
#  > Training time: 3.78 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 87 out of 100
#  ------------
# Loss: 0.003275 [    0]/60000
# Loss: 0.003080 [12800]/60000
# Loss: 0.003196 [25600]/60000
# Loss: 0.003440 [38400]/60000
# Loss: 0.003643 [51200]/60000
#  > Training time: 3.76 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 88 out of 100
#  ------------
# Loss: 0.003202 [    0]/60000
# Loss: 0.003106 [12800]/60000
# Loss: 0.003115 [25600]/60000
# Loss: 0.003403 [38400]/60000
# Loss: 0.003645 [51200]/60000
#  > Training time: 3.74 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 89 out of 100
#  ------------
# Loss: 0.003162 [    0]/60000
# Loss: 0.003059 [12800]/60000
# Loss: 0.003078 [25600]/60000
# Loss: 0.003399 [38400]/60000
# Loss: 0.003645 [51200]/60000
#  > Training time: 3.84 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 90 out of 100
#  ------------
# Loss: 0.003188 [    0]/60000
# Loss: 0.003052 [12800]/60000
# Loss: 0.003137 [25600]/60000
# Loss: 0.003376 [38400]/60000
# Loss: 0.003671 [51200]/60000
#  > Training time: 3.71 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 91 out of 100
#  ------------
# Loss: 0.003263 [    0]/60000
# Loss: 0.003018 [12800]/60000
# Loss: 0.003185 [25600]/60000
# Loss: 0.003615 [38400]/60000
# Loss: 0.003603 [51200]/60000
#  > Training time: 3.89 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 92 out of 100
#  ------------
# Loss: 0.003290 [    0]/60000
# Loss: 0.003020 [12800]/60000
# Loss: 0.003182 [25600]/60000
# Loss: 0.003478 [38400]/60000
# Loss: 0.003568 [51200]/60000
#  > Training time: 3.67 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 93 out of 100
#  ------------
# Loss: 0.003247 [    0]/60000
# Loss: 0.002983 [12800]/60000
# Loss: 0.003043 [25600]/60000
# Loss: 0.003331 [38400]/60000
# Loss: 0.003547 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 94 out of 100
#  ------------
# Loss: 0.003074 [    0]/60000
# Loss: 0.003010 [12800]/60000
# Loss: 0.003020 [25600]/60000
# Loss: 0.003316 [38400]/60000
# Loss: 0.003558 [51200]/60000
#  > Training time: 3.70 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 95 out of 100
#  ------------
# Loss: 0.003058 [    0]/60000
# Loss: 0.003052 [12800]/60000
# Loss: 0.003034 [25600]/60000
# Loss: 0.003296 [38400]/60000
# Loss: 0.003537 [51200]/60000
#  > Training time: 3.73 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 96 out of 100
#  ------------
# Loss: 0.003065 [    0]/60000
# Loss: 0.003077 [12800]/60000
# Loss: 0.003131 [25600]/60000
# Loss: 0.003288 [38400]/60000
# Loss: 0.003633 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 97 out of 100
#  ------------
# Loss: 0.003235 [    0]/60000
# Loss: 0.002938 [12800]/60000
# Loss: 0.003060 [25600]/60000
# Loss: 0.003375 [38400]/60000
# Loss: 0.003527 [51200]/60000
#  > Training time: 3.77 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 98 out of 100
#  ------------
# Loss: 0.003201 [    0]/60000
# Loss: 0.002948 [12800]/60000
# Loss: 0.003140 [25600]/60000
# Loss: 0.003306 [38400]/60000
# Loss: 0.003471 [51200]/60000
#  > Training time: 3.69 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 99 out of 100
#  ------------
# Loss: 0.003147 [    0]/60000
# Loss: 0.002931 [12800]/60000
# Loss: 0.003062 [25600]/60000
# Loss: 0.003255 [38400]/60000
# Loss: 0.003446 [51200]/60000
#  > Training time: 3.85 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Epoch 100 out of 100
#  ------------
# Loss: 0.003016 [    0]/60000
# Loss: 0.002930 [12800]/60000
# Loss: 0.002959 [25600]/60000
# Loss: 0.003229 [38400]/60000
# Loss: 0.003445 [51200]/60000
#  > Training time: 3.77 seconds
#  > Test reconstruction loss: 0.00
# Model ../models/mlpautoenc_sigm_ep100_fmnist.pth stored!
# Done!
