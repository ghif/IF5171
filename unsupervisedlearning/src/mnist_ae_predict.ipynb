# %%
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

import numpy as np

from sklearn.preprocessing import MinMaxScaler

from torchvision import datasets
import torchvision.transforms as T

## My own modules
import viz_utils as vu
import train_utils as tu
import model_utils as mu
###

import imp
imp.reload(vu)
imp.reload(mu)
imp.reload(tu)
# Out:
# /var/folders/wb/ttr9x7pn27q1_rp5vtjfr0s00000gn/T/ipykernel_11969/3262691840.py:22: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'train_utils' from '/Users/mghifary/Work/govtech/codes/AI/unslearning/train_utils.py'>

# %%
DATA_DIR = "../data"
MODEL_DIR = "../models"

EPOCHS = 100
dh = 512
dz = 20

# model_path = os.path.join(MODEL_DIR, "autoenc_sigm_ep%d_h%d_z%d_mnist.pth" % (EPOCHS, dh, dz))
model_path = os.path.join(MODEL_DIR, "autoenc_lin_ep%d_h%d_z%d_mnist.pth" % (EPOCHS, dh, dz))
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Load dataset
training_data = datasets.MNIST(
    root=DATA_DIR, 
    train=True, 
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

test_data = datasets.MNIST(
    root=DATA_DIR,
    train=False,
    download=True,
    transform=T.ToTensor(), #convert to Tensor and normalize to (0, 1)
)

[n, dx1, dx2] = training_data.data.shape

# %%
print(f"Using {DEVICE} device")

# Define model
model = mu.MLPAutoEnc(d_in=dx1*dx2, d_z=dz, d_h=dh).to(DEVICE)
# model = mu.AutoEncSigm(d_in=dx1*dx2, d_z=dz, d_h=dh).to(DEVICE)

model.load_state_dict(torch.load(model_path))
model.eval()

print(model)
# Out:
# Using cpu device
# MLPAutoEnc(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=20, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=20, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=784, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
X2d = training_data.data
X2d_t = test_data.data

# %%
X = torch.reshape(X2d, (-1, dx1 * dx2))
Xt = torch.reshape(X2d_t, (-1, dx1 * dx2))

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
Xn = torch.from_numpy(scaler.fit_transform(X))
Xn_t = torch.from_numpy(scaler.transform(Xt))

# %%
Xn = Xn.float()
Xn_t = Xn_t.float()

# %%
# Reconstruct
Xrec = model(Xn)
Xrec_t = model(Xn_t)

# %%
# Training data
grid = vu.set_grid(X2d, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
# Training reconstruction
V = torch.reshape(Xrec, (-1, dx1, dx2))
grid = vu.set_grid(V, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
# Test data
grid = vu.set_grid(X2d_t, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
# Test reconstruction
V = torch.reshape(Xrec_t, (-1, dx1, dx2))
grid = vu.set_grid(V, num_cells=48)
vu.show(grid)
# Out:
# img_np : 0.0 1.0

# %%
train_rec_loss = torch.mean(torch.sqrt(torch.sum((Xn - Xrec)**2, 1)))
test_rec_loss = torch.mean(torch.sqrt(torch.sum((Xn_t - Xrec_t)**2, 1)))

print(f"Train reconstruction loss: {train_rec_loss:>.2f}")
print(f"Test reconstruction loss: {test_rec_loss:>.2f}")
# Out:
# Train reconstruction loss: 2.06
# Test reconstruction loss: 2.23

# %%
# Check latent codes
Z = model.encoder(Xn)
Zt = model.encoder(Xn_t)

# %%
Zt.min(), Zt.max(), Zt.mean()
# Out:
# (tensor(-14.2571, grad_fn=<MinBackward1>),
#  tensor(11.8018, grad_fn=<MaxBackward1>),
#  tensor(-0.1599, grad_fn=<MeanBackward0>))

# %%
Xdec_t = model.decoder(Zt)

# %% [markdown]
# ## Create Slider UI to Manipulate the Latent Codes

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.display import display

# %%
def decode_and_display(model, zc):
    xc = model.decoder(zc)
    grid = vu.set_grid(torch.reshape(xc, (1, dx1, dx2)), num_cells=1)
    vu.show(grid)
    
def show_image(t):
    zc = Zt[t]
    decode_and_display(model, zc)

# %%
interact(show_image, t=widgets.IntSlider(min=0, max=1000, step=1, value=0));
# Out:
# interactive(children=(IntSlider(value=0, description='t', max=1000), Output()), _dom_classes=('widget-interact…

# %%
Zc = torch.clone(Zt)

# %%
zc = Zc[500]

zw_list = []
for i in range(dz):
    # zw_list.append(widgets.FloatSlider(min=-20, max=20, step=0.1, value=zc[i]))
    zw_list.append(widgets.FloatSlider(min=0, max=1, step=0.01, value=zc[i]))

l2 = int(len(zw_list) / 2)

ui1 = widgets.VBox(zw_list[:l2])
ui2 = widgets.VBox(zw_list[l2:])
ui = widgets.HBox([ui1, ui2])

# %%
def f(**kwargs):
    print(kwargs)
    zc = torch.zeros(dz)
    for key, val in kwargs.items():
        ikey = int(key)
        zc[ikey] = val
        
    decode_and_display(model, zc)

zcodes = {}
for i in range(len(zw_list)):
    key = str(i)
    zcodes[key] = zw_list[i]
out = widgets.interactive_output(f, zcodes)

display(ui, out)
# Out:
# HBox(children=(VBox(children=(FloatSlider(value=0.0, max=1.0, step=0.01), FloatSlider(value=1.0, max=1.0, step…
# Output()

# %% [markdown]
# #### Image Morphing

# %%
def morph(model, xs, xt, n_steps=5):
    """
    Args:
        model (nn.Module): VAE model
        xs (torch.Tensor): source image vector
        xt (torch.Tensor): target image vector
        n_steps (int): number 
    
    """
    # Visualize inputs
    X_input = torch.stack([xs, xt], dim=0)
    X2d = X_input.reshape((-1, dx1, dx2))
    grid = vu.set_grid(X2d, num_cells=2)
    vu.show(grid)
    
    zs = model.encoder(xs)
    zt = model.encoder(xt)
    
    # Linear interpolate on Z codes
    t_list = np.linspace(0, 1, n_steps).tolist()
    z_list = []
    for t in t_list:
        z_list.append(torch.lerp(zs, zt, t))

    Zm = torch.stack(z_list, dim=0)

    # Decode morphed images
    Xm = model.decoder(Zm)
    
    # Visualize the morphed images
    X2d = Xm.reshape((-1, dx1, dx2))
    grid = vu.set_grid(X2d, num_cells=len(z_list))
    vu.show(grid)

# %%
# morph(model, Xn_t[401], Xn_t[300], n_steps=24)
morph(model, Xn_t[2], Xn_t[800], n_steps=24)
# Out:
# img_np : 0.0 1.0
# img_np : 0.0 1.0
